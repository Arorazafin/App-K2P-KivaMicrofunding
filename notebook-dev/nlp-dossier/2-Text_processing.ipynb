# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-package" data-toc-modified-id="Import-package-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import package</a></span></li><li><span><a href="#Load-CSV" data-toc-modified-id="Load-CSV-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load CSV</a></span><ul class="toc-item"><li><span><a href="#Text-preprocessing" data-toc-modified-id="Text-preprocessing-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Text preprocessing</a></span></li></ul></li><li><span><a href="#Save-data" data-toc-modified-id="Save-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Save data</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>  </b>
# </div>

# %% [markdown]
# # Import package

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load CSV

# %%
def read_data(dataset_path):
    df = pd.read_csv(dataset_path,  sep=',')
    #df = df[['rca_content','root_cause_category']] 
    return df

# %%
train_path = 'data_generated_ml/p1Rca.csv'
test_path = 'data_generated_ml/p1Rca_test.csv'

train_data = read_data(train_path)
test_data = read_data(test_path)

# %% [markdown]
# ## Text preprocessing

# %%
import re
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from nltk.corpus import stopwords
from bs4 import BeautifulSoup
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\i0438403\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\i0438403\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def apply_regex(text):
    text = BeautifulSoup(text, "lxml").text
    
    text = text.lower()

    #Folder path
    text = re.sub(r'[a-z]:\\\S+', r' ', text) 
    #non-ASCII
    text = re.sub(r'[^\x00-\x7F]+', r' ', text)
    #ponctuation
    text = re.sub(r',|\.|\(|\)|\:|\-|\_|\&|\?|\*|\>|\<', r' ', text)
    #Number
    text = re.sub(r'\d+', r' ', text)
    #one letter
    text = re.sub(r' [a-z] ', r' ', text)
    #ntlk stopwords
    text = re.sub(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*', r' ', text)
    
    
    return text

# %%
def apply_tokenize(text):
    tokens = []
    for sent in nltk.sent_tokenize(text):
        for word in nltk.word_tokenize(sent):
            if len(word) <= 2:
                continue
            tokens.append(word.lower())
    return tokens

# %%
# Lemmatize with POS Tag
from nltk.corpus import wordnet

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

def apply_lemmatize(text):
    from nltk.stem import WordNetLemmatizer 
    lemmatizer = WordNetLemmatizer()
    text = [lemmatizer.lemmatize(t,get_wordnet_pos(t)) for t in text] 
    return text

# %%
def apply_stopwordsLocal(text, stopw):
    text =  [t for t in text if t not in stopw]
    return text

# %%
stopwordsLocal = ['inc','msc','net','investigation', 'detail','details','action',
                                'performed','date', 'draft','rca','root',
                               'cause','findings','investigated', 'by','root','cause']

# %%
def cleanText(text):
    text = apply_regex(text)
    text = apply_tokenize(text)
    text = apply_lemmatize(text)
    text = apply_stopwordsLocal(text, stopwordsLocal)
    text = ' '.join(map(str, text))
    return text

# %%
string = True
train_data['rca_content_nlp'] = train_data['rca_content'].apply(cleanText)
test_data['rca_content_nlp'] = test_data['rca_content'].apply(cleanText)

# %%
train_data
# Out:
#          problem_id          Number  \
# 0    ITS-PRB0002883  ITS-INC2525678
# 1    ITS-PRB0006202  ITS-INC2001737
# 2    ITS-PRB0006221  ITS-INC2006583
# 3    ITS-PRB0006240  ITS-INC2012930
# 4    ITS-PRB0006294  ITS-INC2040279
# 5    ITS-PRB0006298  ITS-INC2040201
# 6    ITS-PRB0006322  ITS-INC2047668
# 7    ITS-PRB0006350  ITS-INC2069839
# 8    ITS-PRB0006378  ITS-INC2076909
# 9    ITS-PRB0006381  ITS-INC2049973
# 10   ITS-PRB0006387  ITS-INC2064715
# 11   ITS-PRB0006435  ITS-INC2094399
# 12   ITS-PRB0006453  ITS-INC2100855
# 13   ITS-PRB0006466  ITS-INC2079218
# 14   ITS-PRB0006468  ITS-INC2101658
# 15   ITS-PRB0006516  ITS-INC2122055
# 16   ITS-PRB0006524  ITS-INC2125745
# 17   ITS-PRB0006570  ITS-INC2148170
# 18   ITS-PRB0006654  ITS-INC2180750
# 19   ITS-PRB0006683  ITS-INC2187584
# 20   ITS-PRB0006773  ITS-INC2187121
# 21   ITS-PRB0006783  ITS-INC2158264
# 22   ITS-PRB0006785  ITS-INC2221166
# 23   ITS-PRB0006801  ITS-INC2226134
# 24   ITS-PRB0006804  ITS-INC2239808
# 25   ITS-PRB0006829  ITS-INC2228054
# 26   ITS-PRB0006837  ITS-INC2259125
# 27   ITS-PRB0006838  ITS-INC2258078
# 28   ITS-PRB0006921  ITS-INC2292559
# 29   ITS-PRB0006924  ITS-INC2276103
# ..              ...             ...
# 112  ITS-PRB0009124  ITS-INC3232848
# 113  ITS-PRB0009165  ITS-INC3287245
# 114  ITS-PRB0009169  ITS-INC3227961
# 115  ITS-PRB0009199  ITS-INC3304787
# 116  ITS-PRB0009225  ITS-INC3317949
# 117  ITS-PRB0009250  ITS-INC3326777
# 118  ITS-PRB0009311  ITS-INC3369872
# 119  ITS-PRB0009323  ITS-INC3369967
# 120  ITS-PRB0009379  ITS-INC3400255
# 121  ITS-PRB0009384  ITS-INC3424501
# 122  ITS-PRB0009434  ITS-INC3458010
# 123  ITS-PRB0009471  ITS-INC3448198
# 124  ITS-PRB0009480  ITS-INC3482635
# 125  ITS-PRB0009481  ITS-INC3479792
# 126  ITS-PRB0009492  ITS-INC3492565
# 127  ITS-PRB0009512  ITS-INC3502442
# 128  ITS-PRB0009514  ITS-INC3479138
# 129  ITS-PRB0009519  ITS-INC3498768
# 130  ITS-PRB0009528  ITS-INC3521510
# 131  ITS-PRB0009545  ITS-INC3535755
# 132  ITS-PRB0009554  ITS-INC3539000
# 133  ITS-PRB0009569  ITS-INC3540182
# 134  ITS-PRB0009574  ITS-INC3542340
# 135  ITS-PRB0009581  ITS-INC3556731
# 136  ITS-PRB0009589  ITS-INC3559279
# 137  ITS-PRB0009618  ITS-INC3560211
# 138  ITS-PRB0009623  ITS-INC3557620
# 139  ITS-PRB0009651  ITS-INC3563134
# 140  ITS-PRB0009670  ITS-INC3603948
# 141  ITS-PRB0009687  ITS-INC3625605
#
#                                            rca_content  \
# 0     Siemens Ticket has been open (IR 9370883) :  ...
# 1    The PO files are missing in the IDEA path in t...
# 2     Draft RCA: Infor EAM could not communicate to...
# 3      Root Cause - There were faulty hardware comp...
# 4      *  analysis by Support-Scallog:  Indeed, res...
# 5      slots were blocked on 09/01/2019 at 5:36 pm ...
# 6      The root cause of the problem with moving fi...
# 7    Geode+ team Confirmed document (0901ec618be196...
# 8     Unable to go on consumption in PL5 for TRPG p...
# 9     Due to change implemented by MES which caused...
# 10    Background: CEP did not receive ACKI from WES...
# 11     The root cause is an issue on the IDEA datab...
# 12                             no cause was found  3.
# 13   Received the incident on 2019-01-17.As per the...
# 14                   Issue :- : Material document i...
# 15   Root Cause: OEBS forms server got hanged so th...
# 16       Root Cause - F3 application functionality ...
# 17            The problem resulting from a failure ...
# 18    On investigation, it was observed that the jo...
# 19   Root Cause: Database got disconnected so that ...
# 20    Action performed There is a mismatch between ...
# 21   OSIRIS ORACLE Team will provide detailed RCA. ...
# 22    Action performed:  Issue occurred after ITS-C...
# 23     ORTEMS team checked with delmia support team...
# 24   SAP Application(s) sent few payloads with bad ...
# 25   Root Cause: The night planning jobs were start...
# 26   Citrix Metaframe service was not able to reach...
# 27            Root Cause:  As confirmed by ITBSL (A...
# 28   The batch number FA681183 was in red (error) i...
# 29    ORTEMS team checked with delmia support team ...
# ..                                                 ...
# 112  Root cause of this starts with the change in a...
# 113  IDEA services highlighted this exception befor...
# 114    Investigation Details: 5 Why Investigation  ...
# 115  VM LUZSAPPIDAP01 is hosted on ESXi host LUZSAP...
# 116   :              Evidence & Logs I have attache...
# 117   Root Cause - It was Hardware issue on Orange ...
# 118    Root Cause:  Daylight Saving Time was no lon...
# 119  Problem: Users unable to do e-signsWhy? E-Sign...
# 120  The issue occurred during implementation of IT...
# 121  The root cause of this incident was a hung dat...
# 122  N/A since the root cause is not determined.The...
# 123  On 17th November, the AMILY OEBS Database GPAM...
# 124    * At Tibco (Middleware between Source and Lu...
# 125  The GPAAMBRSP_AMBRSPDAY0220_ExpEngus_415 job w...
# 126    Investigation Details:  Why Investigation  F...
# 127   Kaec - Site was unable to print any label in ...
# 128  There are 4 reprogressing fabrication orders(O...
# 129  The customer changed the requirements for new ...
# 130    Investigation Details:  Why Investigation  F...
# 131    Investigation Details:  Why Investigation  F...
# 132  Root Cause â€“ The database instance O2P10896 ...
# 133           Root Cause:         It has been ident...
# 134  VTOM job GPAAMBRSPTPR_AMBRSPTPRXFP_RETOUR did ...
# 135    Root Cause -  The root cause of this issue r...
# 136  Root Cause â€“ The root cause could not be det...
# 137  The root casue of this issue is that OeBS serv...
# 138  The issue occurred due to lack of free space o...
# 139    Root Cause:   Issue occurred due to multiple...
# 140    Root Cause:  It was a bad SFP which caused p...
# 141  Application team could not access the server a...
#
#                                         root_cause  \
# 0                                   Server failure
# 1                    Missing Setting/Wrong setting
# 2                           Archive log space full
# 3                                     server crash
# 4                              Disk space too high
# 5                          Wrong application usage
# 6                               Wrong Job schedule
# 7                      Infrastructure Obsolescence
# 8                          Root Cause Unidentified
# 9       regression from application planned change
# 10                               Failure on Server
# 11                          Oracle Tablespace full
# 12                         Root Cause Unidentified
# 13      regression from application planned change
# 14                                      Wrong data
# 15                        Application Obsolescence
# 16                     Web Server - Out of memory
# 17                                  Server failure
# 18                         Wrong application usage
# 19                        Application Obsolescence
# 20                         Wrong application usage
# 21                                     CPU reached
# 22   Regression from infrastructure planned change
# 23                         Wrong application usage
# 24                         Root Cause Unidentified
# 25                              Wrong Job schedule
# 26                     Infrastructure Obsolescence
# 27                                Deployment issue
# 28                              Wrong data mapping
# 29                         Wrong application usage
# ..                                             ...
# 112     regression from application planned change
# 113                                    In progress
# 114                       Application Obsolescence
# 115                                  Power failure
# 116                                    In progress
# 117                                  Network issue
# 118                           Daylight Saving time
# 119                         Certificate Expiration
# 120  Regression from infrastructure planned change
# 121                                     Wrong data
# 122                        Root Cause Unidentified
# 123                  Missing Setting/Wrong setting
# 124                                    In progress
# 125                     Application process freeze
# 126                                    In progress
# 127                         Certificate Expiration
# 128                                     Wrong data
# 129                              Certificate issue
# 130                                    In progress
# 131                                  Power failure
# 132                                       db issue
# 133                               Wrong Permission
# 134             Application service/ Process issue
# 135                     Application process freeze
# 136                                       db issue
# 137                     Server - db capacity issue
# 138                    Infrastructure Obsolescence
# 139                                 Firewall issue
# 140                    Infrastructure Obsolescence
# 141                      Missing DNS configuration
#
#                           root_cause_type  \
# 0                                Hardware
# 1                     Configuration Issue
# 2                          Resource Issue
# 3                                Hardware
# 4                          Resource Issue
# 5                             Human Error
# 6                              Scheduling
# 7                      Outdated Component
# 8                      Cause Unidentified
# 9                             Application
# 10                               Hardware
# 11                         Resource Issue
# 12                     Cause Unidentified
# 13                            Application
# 14                             Data Issue
# 15                     Outdated Component
# 16                         Resource Issue
# 17                               Hardware
# 18                            Human Error
# 19                     Outdated Component
# 20                            Human Error
# 21                         Resource Issue
# 22                            Application
# 23                            Human Error
# 24                     Cause Unidentified
# 25                             Scheduling
# 26                     Outdated Component
# 27                  Change implementation
# 28                             Data Issue
# 29                            Human Error
# ..                                    ...
# 112                           Application
# 113                      Not yet Analyzed
# 114                    Outdated Component
# 115                        External event
# 116                      Not yet Analyzed
# 117                              Hardware
# 118                   Configuration Issue
# 119                     Expired component
# 120                           Application
# 121                            Data Issue
# 122                    Cause Unidentified
# 123                   Configuration Issue
# 124                      Not yet Analyzed
# 125               Application Performance
# 126                      Not yet Analyzed
# 127                     Expired component
# 128                            Data Issue
# 129  Certificate /Password Mgt/permission
# 130                      Not yet Analyzed
# 131                        External event
# 132                        Resource Issue
# 133                      Permission issue
# 134                    Cause Unidentified
# 135               Application Performance
# 136                        Resource Issue
# 137                        Resource Issue
# 138                    Outdated Component
# 139                   Configuration Issue
# 140                    Outdated Component
# 141                   Configuration Issue
#
#                       root_cause_category  \
# 0               Ressources unavailability
# 1                          Change Control
# 2               Ressources unavailability
# 3               Ressources unavailability
# 4               Ressources unavailability
# 5                                   Usage
# 6                              Scheduling
# 7                            obSolescence
# 8                    Investigation failed
# 9                          Change Control
# 10              Ressources unavailability
# 11              Ressources unavailability
# 12                   Investigation failed
# 13                         Change Control
# 14                                  Usage
# 15                           obSolescence
# 16              Ressources unavailability
# 17              Ressources unavailability
# 18                                  Usage
# 19                           obSolescence
# 20                                  Usage
# 21              Ressources unavailability
# 22                         Change Control
# 23                                  Usage
# 24                   Investigation failed
# 25                             Scheduling
# 26                           obSolescence
# 27                                  Other
# 28                                  Usage
# 29                                  Usage
# ..                                    ...
# 112                        Change Control
# 113                      Not yet Analyzed
# 114                          obSolescence
# 115                                 Other
# 116                      Not yet Analyzed
# 117             Ressources unavailability
# 118                        Change Control
# 119  Certificate /Password Mgt/permission
# 120                        Change Control
# 121                                 Usage
# 122                  Investigation failed
# 123                        Change Control
# 124                      Not yet Analyzed
# 125                  Investigation failed
# 126                      Not yet Analyzed
# 127  Certificate /Password Mgt/permission
# 128                                 Usage
# 129  Certificate /Password Mgt/permission
# 130                      Not yet Analyzed
# 131                                 Other
# 132             Ressources unavailability
# 133  Certificate /Password Mgt/permission
# 134                  Investigation failed
# 135                  Investigation failed
# 136             Ressources unavailability
# 137             Ressources unavailability
# 138                          obSolescence
# 139                        Change Control
# 140                          obSolescence
# 141                        Change Control
#
#                                        rca_content_nlp
# 0    siemens ticket open problem communication orac...
# 1    file miss idea path server luzsappidap miss fi...
# 2    infor eam could communicate oracle server orac...
# 3    faulty hardware component sfp cable vcm perfor...
# 4    analysis support scallog indeed restart applic...
# 5             slot block perform tray release unlocked
# 6    problem move file directory /xfp/sanofi/etudes...
# 7    geode+ team confirm document xml publish end a...
# 8    unable consumption trpg plant waighing idoc in...
# 9    due change implement me issue incorrect quanti...
# 10   background cep receive acki wes job start deli...
# 11   issue idea database tablespace extension enoug...
# 12                                               found
# 13   receive incident per preliminary analyse issue...
# 14   issue material document articulate wave system...
# 15                oebs form server get hang responsive
# 16   application functionality take care three part...
# 17   problem result failure main dns server fell im...
# 18   observe job mcsr upd february get fail due log...
# 19   database get disconnect sesam interface progra...
# 20   perform mismatch qmhu inspection stock due bus...
# 21   osiris oracle team provide detailed still go s...
# 22   perform issue occur chg carry update kalabie s...
# 23   ortems team checked delmia support team analys...
# 24   sap application sent payload bad data since ba...
# 25               night planning job start run day time
# 26   citrix metaframe service able reach datastore ...
# 27   confirm itbsl andrea goupil issue occur deploy...
# 28   batch number red error pdw vaccine visualizati...
# 29   ortems team checked delmia support team told c...
# ..                                                 ...
# 112  start change formula mbr increase amount data ...
# 113  idea service highlight exception terminate err...
# 114  finding investigate file bloked tranfer file m...
# 115  luzsappidap host esxi host luzsappesxp however...
# 116  evidence log attach awr report hour clearly sh...
# 117  hardware issue orange pop faulty module networ...
# 118  daylight save time longer use brazil april day...
# 119  problem user unable signswhy sign url work sig...
# 120  issue occur implementation chg aim network red...
# 121  incident hung database session request xxof la...
# 122  since determine applicable since find performe...
# 123  november amily oebs database gpamy go due serv...
# 124  tibco middleware source luna file processor er...
# 125  gpaambrsp ambrspday expengus job workflow fail...
# 126  finding investigate production line lot stuck ...
# 127  kaec site unable print label production enviro...
# 128  reprogressing fabrication order sublots declar...
# 129  customer change requirement new certificate re...
# 130  finding investigate production batch order dat...
# 131  finding investigate production line lot stuck ...
# 132  database instance terminate abnormally temp fi...
# 133  identifed execution permission miss group righ...
# 134  vtom job gpaambrsptpr ambrsptprxfp retour proc...
# 135  issue remains undetermined window team suspect...
# 136  could determine application team oracle team f...
# 137  casue issue oebs server ambsgpampa insufficien...
# 138  issue occur due lack free space cgnssanetiq sp...
# 139  issue occur due multiple contribute factor inc...
# 140  bad sfp path error result situation single lin...
# 141  application team could access server request o...
#
# [142 rows x 7 columns]

# %%
test_data
# Out:
#             Number      problem_id  \
# 0   ITS-INC3648484  ITS-PRB0009342
# 1   ITS-INC3644991  ITS-PRB0009712
# 2   ITS-INC3654989  ITS-PRB0009718
# 3   ITS-INC3676684  ITS-PRB0009745
# 4   ITS-INC3696405  ITS-PRB0009758
# 5   ITS-INC3735137  ITS-PRB0009862
# 6   ITS-INC3758732  ITS-PRB0009868
# 7   ITS-INC3762244  ITS-PRB0009879
# 8   ITS-INC3800514  ITS-PRB0009940
# 9   ITS-INC3806935  ITS-PRB0009958
# 10  ITS-INC3819554  ITS-PRB0009985
# 11  ITS-INC3836232  ITS-PRB0010008
# 12  ITS-INC3824312  ITS-PRB0010016
# 13  ITS-INC3805104  ITS-PRB0010023
# 14  ITS-INC3853673  ITS-PRB0010071
# 15  ITS-INC3856770  ITS-PRB0010146
# 16  ITS-INC3860587  ITS-PRB0010164
# 17  ITS-INC3938789  ITS-PRB0010337
# 18  ITS-INC3948495  ITS-PRB0010338
# 19  ITS-INC3923210  ITS-PRB0010341
# 20  ITS-INC4101188  ITS-PRB0010632
# 21  ITS-INC4123337  ITS-PRB0010673
# 22  ITS-INC4131130  ITS-PRB0010692
# 23  ITS-INC4145037  ITS-PRB0010720
# 24  ITS-INC4174625  ITS-PRB0010746
# 25  ITS-INC4108983  ITS-PRB0010798
# 26  ITS-INC4243197  ITS-PRB0010840
# 27  ITS-INC4256066  ITS-PRB0010860
# 28  ITS-INC4270822  ITS-PRB0010882
# 29  ITS-INC4280081  ITS-PRB0010910
#
#                                           rca_content  \
# 0     * Primary issue is on XSPW10W182S as the pri...
# 1   Cluster service failed for unknown reason at 5...
# 2   Investigation performed by Oracle team reveale...
# 3   Master applications use LDAP web service URL f...
# 4     Investigation Details:  Why Investigation  F...
# 5    Root Cause: \t VTOM agent was down as File Sy...
# 6     Investigation Details:  Why Investigation  F...
# 7   The issue comes from a problem with WebService...
# 8     * Issue is caused because of Program Error. ...
# 9     Root Cause:  The USERS tablespace on databas...
# 10   Root Cause:     Tablespace and File system ra...
# 11  Analysis :Sequence of the event of SDU Ã¢â‚¬Å“...
# 12    Root Cause:   - Database server xspl11f170tn...
# 13  Abbreviations:RSDS Ã¢â‚¬â€œ  Reference Standar...
# 14    Root Cause:  The Enterprise Messaging Server...
# 15  The lost communication as well as the licensin...
# 16   Investigation Details:  ITS-INC3860587 Why In...
# 17  Root Cause: The default health monitor of the ...
# 18      ROOT CAUSE :  From the events and logs fro...
# 19  Techical root Ã¢â‚¬â€œ cause - Documented in I...
# 20   INVESTIGATION DETAILS:  Why Investigation  Fi...
# 21  ITS-INC4123337During the issue reported we che...
# 22  Batch job HCSR3UPD_I0460ITPA  which was execut...
# 23  Root Cause Ã¢â‚¬â€œ Oracle team updated that d...
# 24  Root Cause:An online activity (RITM1918879) wa...
# 25    Root Cause:   * The managed storage server w...
# 26  Root Cause: Windows team have found that the s...
# 27  Root Cause:The application server AMPSAPPSERP0...
# 28    ROOT CAUSE  The high CPU utilization caused ...
# 29    ROOT CAUSE               Labels were not pri...
#
#                             root_cause      root_cause_type  \
# 0              Root Cause Unidentified   Cause Unidentified
# 1          Infrastructure Obsolescence   Outdated Component
# 2          Infrastructure Obsolescence   Outdated Component
# 3                    Failure on Server             Hardware
# 4               Standard Editor Defect       Change Control
# 5                        Network issue             Hardware
# 6             Application Obsolescence   Outdated Component
# 7   regression from application change          Application
# 8   regression from application change          Application
# 9          Overload activity on server       Resource Issue
# 10                       Network issue             Hardware
# 11                         Human Error          Human Error
# 12                  Application defect          Application
# 13                         Human Error          Human Error
# 14         Overload activity on server       Resource Issue
# 15                         Human Error          Human Error
# 16       Missing Setting/Wrong setting  Configuration Issue
# 17             Root Cause Unidentified   Cause Unidentified
# 18          Server - db capacity issue       Resource Issue
# 19  regression from application change          Application
# 20             Root Cause Unidentified   Cause Unidentified
# 21                 Disk space too high       Resource Issue
# 22  regression from application change          Application
# 23             Root Cause Unidentified   Cause Unidentified
# 24                 Disk space too high       Resource Issue
# 25             Root Cause Unidentified   Cause Unidentified
# 26         Infrastructure Obsolescence   Outdated Component
# 27             Root Cause Unidentified   Cause Unidentified
# 28         Infrastructure Obsolescence   Outdated Component
# 29                      Firewall issue  Configuration Issue
#
#           root_cause_category  \
# 0        Investigation failed
# 1                obSolescence
# 2                obSolescence
# 3   Ressources unavailability
# 4              Change Control
# 5   Ressources unavailability
# 6                obSolescence
# 7              Change Control
# 8              Change Control
# 9   Ressources unavailability
# 10  Ressources unavailability
# 11                      Usage
# 12             Change Control
# 13                      Usage
# 14  Ressources unavailability
# 15                      Usage
# 16             Change Control
# 17       Investigation failed
# 18  Ressources unavailability
# 19             Change Control
# 20       Investigation failed
# 21  Ressources unavailability
# 22             Change Control
# 23       Investigation failed
# 24  Ressources unavailability
# 25       Investigation failed
# 26               obSolescence
# 27       Investigation failed
# 28               obSolescence
# 29             Change Control
#
#                                       rca_content_nlp
# 0   primary issue xspw print service start automat...
# 1   cluster service fail unknown reason cluster ru...
# 2   perform oracle team reveal issue disc inaccess...
# 3   master application use ldap web service url us...
# 4   finding investigate production case serial go ...
# 5   vtom agent file system /products/exploit vtom ...
# 6   finding investigate production work order 'rr ...
# 7   issue come problem webservice use sap phenix t...
# 8   issue program error part demand ritm change ma...
# 9   user tablespace database suzxibp fill till due...
# 10  tablespace file system ran freespace result da...
# 11  analysis sequence event sdu ritm update status...
# 12  database server xspl hung state since feb even...
# 13  abbreviation rsds reference standard data shee...
# 14  enterprise message server em xsph part tibco g...
# 15  lose communication well licensing issue conseq...
# 16  finding investigate batch order file miss app ...
# 17  default health monitor amer internal load bala...
# 18  event log server versappvtmp server total comm...
# 19  techical document conformity certificate sap u...
# 20  finding investigate packaging packaging line s...
# 21  issue report checked senitiq service log find ...
# 22  batch job hcsr upd itpa execute athena system ...
# 23  oracle team update transition ort session atos...
# 24  online activity ritm perform unix team add spa...
# 25  manage storage server reboot month probable re...
# 26  window team found server virtualized network i...
# 27  application server ampsappserp reachable ping ...
# 28  high cpu utilization server tousappserp get mi...
# 29  label printing luna site lissappsnqp incident ...

# %% [markdown]
# # Save data

# %%
train_data.to_csv('data_generated_ml/p1Rca_nlp.csv')
test_data.to_csv('data_generated_ml/p1Rca_test_nlp.csv')
